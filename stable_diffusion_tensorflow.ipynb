# %%
# !pip install git+https://github.com/divamgupta/stable-diffusion-tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/divamgupta/stable-diffusion-tensorflow to /tmp/pip-req-build-x6sd65wy
#   Running command git clone -q https://github.com/divamgupta/stable-diffusion-tensorflow /tmp/pip-req-build-x6sd65wy

# %%
# !pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install tensorflow_addons
# !pip install ftfy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from stable_diffusion_tf.stable_diffusion import StableDiffusion
from PIL import Image

generator = StableDiffusion(
    img_height=512,
    img_width=512,
    jit_compile=False,
)
img = generator.generate(
    "An astronaut riding a horse",
    num_steps=50,
    unconditional_guidance_scale=7.5,
    temperature=1,
    batch_size=1,
)
Image.fromarray(img[0]).save("output.png")
# Out:
# ...
#   0   1: 100%|██████████| 50/50 [01:11<00:00,  1.42s/it]

# %%
Image.open("output.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7F66143E7050>

# %%
img = generator.generate(
    "Beautiful girl doing computer programming at sea beach wearing red dress",
    num_steps=50,
    unconditional_guidance_scale=7.5,
    temperature=1,
    batch_size=1,
)
Image.fromarray(img[0]).save("output.png")
Image.open("output.png")
# Out:
#   0   1: 100%|██████████| 50/50 [00:53<00:00,  1.07s/it]
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7F661439A4D0>

# %%
img = generator.generate(
    "kingkong fighting with spider man in newyork city",
    num_steps=50,
    unconditional_guidance_scale=7.5,
    temperature=1,
    batch_size=1,
)
Image.fromarray(img[0]).save("output.png")
Image.open("output.png")
# Out:
#   0   1: 100%|██████████| 50/50 [00:54<00:00,  1.09s/it]
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7F66143AF590>
